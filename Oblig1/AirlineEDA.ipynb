# %% [markdown]
# # EDA
# I've split the EDA into 3 separate parts:
# - Understanding the dataset
# - Cleaning the dataset
# - Feature analysis
#     - Univariate
#     - Multivariate

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv(r'C:\Users\marku\Desktop\ML\MLGit\datasets\airline.csv')

# %% [markdown]
# # Understanding the dataset

# %%
df.shape
# Out:
# (103904, 25)

# %% [markdown]
# The dataset has 103904 rows and 25 columns.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# Name of each column.

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %% [markdown]
# Indicates which datatype each column has
# - int64: normal numeric value
# - object: a categorical value

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %% [markdown]
# .describe() gives us information about how many values each column contains, the mean, standard deviation, and different percentiles. .describe() can only handle numeric values.
# Doesn't seem like the dataset contains any missing value. (Will double check)
# I cannot see any strange values.

# %% [markdown]
# # Cleaning the dataset

# %% [markdown]
# ## Feature Selection

# %%
df = df.drop(['id', 'Unnamed: 0'], axis=1)

# %% [markdown]
# Removing columns I know will not make a difference

# %% [markdown]
# ## Null-values

# %%
df.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
def handle_null_median(df):
    # Need to set inplace=True, so it doesn't create a copy of the dataframe. Tried without and this led to null-values not being removed
    df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median(), inplace=True)

    return  df

# Sets null values equal to the mean of that column
def handle_null_mean(df):
    df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mean(), inplace=True)

    return  df

# Function to drop all rows with at least 1 null value. (Removes way to many rows, so isn't a good option)
def null_values_drop(df):
    df_copy = df.copy()
    df_drop = df_copy.dropna(axis=0, how='any')

    return df_drop

df = handle_null_mean(df)
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %% [markdown]
# Here I've created three functions to handle missing value for the given column. All three strategies would work fine on this dataset since it so big and so few missing value.
# I chose to handle the missing value with the mean value for that row, but I could might as well have used one of the other

# %% [markdown]
# ## Feature Engineering

# %%
df['Late Departure'] = 0
df.loc[df['Departure Delay in Minutes'] != 0, 'Late Departure' ] = 1
df = df.drop('Departure Delay in Minutes', axis=1)

df['Late Arrival'] = 0
df.loc[df['Arrival Delay in Minutes'] != 0, 'Late Arrival' ] = 1
df = df.drop('Arrival Delay in Minutes', axis=1)

df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %% [markdown]
# Created two categorical columns: Late Departure and Late Arrival
# I've created these to see if it matters how late the plain arrived or departed.

# %%
pd.cut(df['Flight Distance'], 10)
# Out:
# 0          (26.048, 526.2]
# 1          (26.048, 526.2]
# 2         (1021.4, 1516.6]
# 3          (526.2, 1021.4]
# 4          (26.048, 526.2]
#                 ...
# 103899     (26.048, 526.2]
# 103900    (2011.8, 2507.0]
# 103901    (1516.6, 2011.8]
# 103902     (526.2, 1021.4]
# 103903    (1516.6, 2011.8]
# Name: Flight Distance, Length: 103904, dtype: category
# Categories (10, interval[float64, right]): [(26.048, 526.2] < (526.2, 1021.4] < (1021.4, 1516.6] < (1516.6, 2011.8] ... (3002.2, 3497.4] < (3497.4, 3992.6] < (3992.6, 4487.8] < (4487.8, 4983.0]]

# %%
# Got the idea of splitting age into bins from: https://www.kaggle.com/code/sinakhorami/titanic-best-working-classifier, but seems like a common practice called Binning, where you put a range of values into a bin
def bins(df): # This is kind of feature engineering as well
    df['FlightDistanceGroup'] = 0
    df.loc[df['Flight Distance'] < 526.2, 'FlightDistanceGroup' ] = 0
    df.loc[(df['Flight Distance'] >= 526.2) & (df['Flight Distance'] < 1021.4), 'FlightDistanceGroup'] = 1
    df.loc[(df['Flight Distance'] >= 1021.4) & (df['Flight Distance'] < 1516.6), 'FlightDistanceGroup'] = 2
    df.loc[(df['Flight Distance'] >= 1516.6) & (df['Flight Distance'] < 2011.8), 'FlightDistanceGroup'] = 3
    df.loc[(df['Flight Distance'] >= 2011.8) & (df['Flight Distance'] < 2507.0), 'FlightDistanceGroup'] = 4
    df.loc[(df['Flight Distance'] >= 2507) & (df['Flight Distance'] < 3002.2), 'FlightDistanceGroup'] = 5
    df.loc[(df['Flight Distance'] >= 3002.2) & (df['Flight Distance'] < 3497.4), 'FlightDistanceGroup'] = 6
    df.loc[(df['Flight Distance'] >= 3497.4) & (df['Flight Distance'] < 3992.6), 'FlightDistanceGroup'] = 7
    df.loc[(df['Flight Distance'] >= 3992.6) & (df['Flight Distance'] < 4487.8), 'FlightDistanceGroup'] = 8
    df.loc[df['Flight Distance'] >=  4487.8, 'FlightDistanceGroup'] = 9

    df = df.drop(columns=['Flight Distance'])

    return df

df = bins(df)
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    Male  disloyal Customer   25  Business travel  Business
# 2  Female     Loyal Customer   26  Business travel  Business
# 3  Female     Loyal Customer   25  Business travel  Business
# 4    Male     Loyal Customer   61  Business travel  Business
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  ...  \
# 0                       3              1               5  ...
# 1                       3              3               1  ...
# ...

# %% [markdown]
# I've done this binning since this makes continious values to categorical ones. This makes it possible to look at the distribution of the column much easier. This also makes it possible to do feature correlation analysis.

# %% [markdown]
# ## Encoding

# %%
df['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
df['Type of Travel'].unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
df['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
df['Class'].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
df['Gender'] = df['Gender'].replace(['Female', 'Male'], [0,1])
df['Customer Type'] = df['Customer Type'].replace(['Loyal Customer', 'disloyal Customer'], [0,1])
df['Type of Travel'] = df['Type of Travel'].replace(['Personal Travel', 'Business travel'], [0,1])
df['Class'] = df['Class'].replace(['Eco Plus', 'Business', 'Eco'], [0,1,2])
df['satisfaction'] = df['satisfaction'].replace(['satisfied', 'neutral or dissatisfied'], [1,0])
df
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  \
# 0            1              0   13               0      0
# 1            1              1   25               1      1
# 2            0              0   26               1      1
# 3            0              0   25               1      1
# 4            1              0   61               1      1
# ...        ...            ...  ...             ...    ...
# 103899       0              1   23               1      2
# 103900       1              0   49               1      1
# 103901       1              1   30               1      1
# 103902       0              1   22               1      2
# 103903       1              0   27               1      1
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 0                           3                                  4
# 1                           3                                  2
# 2                           2                                  2
# ...

# %% [markdown]
# # Feature Analysis

# %% [markdown]
# ## Univariate Analysis

# %%
fig = plt.figure(figsize = (48,32))
ax = fig.gca()
df.hist(ax = ax)
# Out:
# C:\Users\marku\AppData\Local\Temp\ipykernel_14884\3930175961.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax = ax)
# array([[<AxesSubplot:title={'center':'Gender'}>,
#         <AxesSubplot:title={'center':'Customer Type'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Type of Travel'}>,
#         <AxesSubplot:title={'center':'Class'}>],
#        [<AxesSubplot:title={'center':'Inflight wifi service'}>,
#         <AxesSubplot:title={'center':'Departure/Arrival time convenient'}>,
#         <AxesSubplot:title={'center':'Ease of Online booking'}>,
#         <AxesSubplot:title={'center':'Gate location'}>,
#         <AxesSubplot:title={'center':'Food and drink'}>],
#        [<AxesSubplot:title={'center':'Online boarding'}>,
#         <AxesSubplot:title={'center':'Seat comfort'}>,
#         <AxesSubplot:title={'center':'Inflight entertainment'}>,
# ...

# %% [markdown]
# Probably the most interesting plot for this dataset is the distribution. Distribution plots only works for categorical features. For this dataset that means that the plot contains almost every column.
#
# In this plot we can see that most columns are fearly distributed. Normally bad distributions can lead to bad models due to training and test data containing a small sample of a value from a column, but for such a big dataset as this one, I don't think this will lead to any problems.
#
# The columns which are poorly distributed are Customer type, Type of travel, Class and Flight distande group.

# %% [markdown]
# ## Multivariate Analysis

# %%
corr = df.corr()
plt.figure(figsize=(32, 12))
heatmap = sns.heatmap(corr, annot=True)

# %% [markdown]
# The dataset contains way to many columns to look at correlations between each and every column, so I've chosen a few to take a look at.
#
# From this correlation plot we can see:
# - Gender has no clear correlation with any other feature
# - Age has a positive correlation with Online boarding. Meaning has a person gets older, the higher it scores online boarding
# - Inflight wifi service and ease of online booking has a great positive correlation. Meaning people who scored ease of booking online high, also scored inflight wifi services high
# - The higher ticket class(higher is worse) the worse one generally would score other features.
# - If a person had high seat comfort they would one average score more features high. The same goes for inflight entertainment.
# - Most features are highly correlated with the ground truth.
# - My two feature engineered features has close to zero correlation with satisfaction. This indicates that the amount of minutes a plane arrives or departs late makes a big difference for people.
#
# For a lot of features, if a person scored one feature really high, it seems like the person was more likely to score other features high, especially features which are semi in the same category.
#
# From this correlation heatmap I could safely remove these columns due to a lack of correlation iwth other features and the ground truth:
# - Gender
# - Late arrival
# - Late departure
#
# No idendpendent variable has such a high correlation with another independent variable that I could remove one of them without loosing information.

# %% [markdown]
# # The Final Dataset

# %%
df
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  \
# 0            1              0   13               0      0
# 1            1              1   25               1      1
# 2            0              0   26               1      1
# 3            0              0   25               1      1
# 4            1              0   61               1      1
# ...        ...            ...  ...             ...    ...
# 103899       0              1   23               1      2
# 103900       1              0   49               1      1
# 103901       1              1   30               1      1
# 103902       0              1   22               1      2
# 103903       1              0   27               1      1
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# 0                           3                                  4
# 1                           3                                  2
# 2                           2                                  2
# ...
